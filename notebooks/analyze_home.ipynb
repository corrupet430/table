# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import modules.utils as utils

# %%
table_df =  pd.read_csv('C:/Users/VivoBook/PycharmProjects/pythonProject3/table.csv')

# %%
utils.print_profit_home_result(table_df)
# Out:
# Count: 1012
# AxesSubplot(0.125,0.125;0.775x0.755)
